# %% [markdown]
# <a href="https://colab.research.google.com/github/dsnato/estatistica/blob/main/amostragem_sistematica.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Formação Cientista de Dados
# ## Amostragem sistemática

# %%
# Importação das bibliotecas

import numpy as np
import pandas as pd
from math import ceil

# %%
# Carregar base de dados que será utilizada

base = pd.read_csv('iris.csv')
base.head(10)
# Out:
#    sepal length  sepal width  petal length  petal width        class
# 0           5.1          3.5           1.4          0.2  Iris-setosa
# 1           4.9          3.0           1.4          0.2  Iris-setosa
# 2           4.7          3.2           1.3          0.2  Iris-setosa
# 3           4.6          3.1           1.5          0.2  Iris-setosa
# 4           5.0          3.6           1.4          0.2  Iris-setosa
# 5           5.4          3.9           1.7          0.4  Iris-setosa
# 6           4.6          3.4           1.4          0.3  Iris-setosa
# 7           5.0          3.4           1.5          0.2  Iris-setosa
# 8           4.4          2.9           1.4          0.2  Iris-setosa
# 9           4.9          3.1           1.5          0.1  Iris-setosa

# %%
# Criação das variáveis para representar a população, a amostra e o valor de k

populacao = 150
amostra = 15
k = ceil(populacao / amostra)
print(k)
# Out:
# 10

# %%
# Definição do valor randômico para inicializar a amostra, iniciando em 1 até k + 1
r = np.random.randint(low = 1, high = k + 1, size = 1)
print(r)
type(r)
# Out:
# [7]
# numpy.ndarray

# %%
# Criamos um for para somar os próximos valores, baseado no primeiro valor r que foi definido acima

acumulador = r[0]
sorteados = []
for i in range(amostra):
    print(acumulador)
    sorteados.append(acumulador)
    acumulador += k
print(sorteados)
# Out:
# 7
# 17
# 27
# 37
# 47
# 57
# 67
# 77
# 87
# 97
# 107
# 117
# 127
# 137
# 147
# [np.int64(7), np.int64(17), np.int64(27), np.int64(37), np.int64(47), np.int64(57), np.int64(67), np.int64(77), np.int64(87), np.int64(97), np.int64(107), np.int64(117), np.int64(127), np.int64(137), np.int64(147)]

# %%
len(sorteados)
# Out:
# 15

# %%
# Criamos a base_final somente com os valores sorteados

base_final = base.loc[sorteados]
base_final
# Out:
#      sepal length  sepal width  petal length  petal width            class
# 7             5.0          3.4           1.5          0.2      Iris-setosa
# 17            5.1          3.5           1.4          0.3      Iris-setosa
# 27            5.2          3.5           1.5          0.2      Iris-setosa
# 37            4.9          3.1           1.5          0.1      Iris-setosa
# 47            4.6          3.2           1.4          0.2      Iris-setosa
# 57            4.9          2.4           3.3          1.0  Iris-versicolor
# 67            5.8          2.7           4.1          1.0  Iris-versicolor
# 77            6.7          3.0           5.0          1.7  Iris-versicolor
# 87            6.3          2.3           4.4          1.3  Iris-versicolor
# 97            6.2          2.9           4.3          1.3  Iris-versicolor
# 107           7.3          2.9           6.3          1.8   Iris-virginica
# ...
