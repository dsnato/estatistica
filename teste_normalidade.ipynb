# %% [markdown]
# <a href="https://colab.research.google.com/github/dsnato/estatistica/blob/main/teste_normalidade.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Formação Cientista de Dados
# ## Teste de Normalidade (Teste de Distribuição Normal)

# %%
# Importação das bibliotecas: matplotlib para geração de gráficos
import matplotlib.pyplot as plt
from scipy import stats
from scipy.stats import norm, skewnorm

# %%
# Criação de uma variável com dados em uma distribuição normal com a função rvs (100 elementos)
dados = norm.rvs(size = 100)
dados
# Out:
# array([ 0.57572514, -0.28515243, -0.04046717,  0.80023469,  1.67989104,
#        -0.32649046, -0.47196173,  0.22717434, -2.03096894,  0.8744442 ,
#        -0.41430953,  0.24974709, -1.25337897,  1.21783545,  0.79019533,
#        -0.92612091, -0.18021705, -0.99797062,  2.04290858, -0.57034864,
#         2.02804108, -0.07504737,  0.43941396, -0.21454011,  0.71440098,
#         0.55175251,  0.66965313, -0.00604525, -1.51352382,  0.37068463,
#         1.98224666,  0.16189797, -1.25926291,  0.47016367,  0.0912826 ,
#         0.34002611, -0.18798113,  1.09608094, -0.62481836, -0.2053376 ,
#         0.24857302,  0.66388635, -0.6239981 ,  1.1267672 ,  0.60129117,
#         0.62325724,  1.60586931, -0.87942943, -1.58447934, -1.89214168,
#         1.24463462,  1.79112872,  2.78017319, -1.11100156,  0.37384213,
#         0.25087759, -0.21865343,  1.13425254, -0.94140327, -0.98983992,
#         0.0114336 , -1.08135044, -2.0709016 ,  0.36120069,  0.06844568,
#         1.30187246, -1.34971123, -1.09307563,  0.9456412 ,  0.83680273,
#        -0.26583452,  2.53440673, -0.64869566, -0.13252604,  0.4347955 ,
#         1.42958628,  0.96359101, -0.46887174,  0.4346064 ,  1.21751612,
#         2.17878873, -1.37469529, -1.0710412 , -0.73624256, -0.64627574,
#         0.08996041, -0.17476995, -0.4836572 ,  0.97323975,  1.37761624,
#         0.92114307,  1.29411253, -0.55982542,  0.3584046 , -1.47367326,
#        -0.77380292, -0.26575127,  1.17118382, -0.60652566, -1.5649888 ])

# %%
# Histograma
plt.hist(dados, bins = 20)
plt.title('Dados')
# Out:
# Text(0.5, 1.0, 'Dados')

# %%
# Geração de gráfico para verifica se a distribuição é normal
fig, ax = plt.subplots()
stats.probplot(dados, fit=True, plot=ax)
plt.show()

# %%
# Execução do teste de Shapiro-Wilk
# Segundo argumento é o valor de p, não há como rejeitar a hipótese nula
stats.shapiro(dados)
# Out:
# ShapiroResult(statistic=np.float64(0.9925994647996509), pvalue=np.float64(0.8627665785564398))

# %% [markdown]
# ## Dados não normais

# %%
dados2 = skewnorm.rvs(4, size = 100)

# %%
# Histograma
plt.hist(dados2, bins = 20)
plt.title('Dados')
# Out:
# Text(0.5, 1.0, 'Dados')

# %%
# Geração de gráfico para verificar se a distribuição é normal
fig, ax = plt.subplots()
stats.probplot(dados2, fit=True, plot=ax)
plt.show()

# %%
stats.shapiro(dados2)
# Out:
# ShapiroResult(statistic=np.float64(0.91280911388538), pvalue=np.float64(5.9643376968843026e-06))
